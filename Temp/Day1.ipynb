# %% [markdown]
# # Day 1
#
# We calculate the log(likelihood) on each gridding point of (mean(vr), dispersion(vr))

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data_path = '../Materials/data/'

# %%
df = pd.read_csv(data_path+'Cas3_total.csv')

# %%
plt.figure()
plt.hist(df['vr']);

# %%
ind_dg = df['vr'] <= -300

# %%
dg = df[ind_dg]
vr_cas3 = np.array(dg['vr'])
print (len(vr_cas3))
# Out:
# 212

# %%
plt.figure()
plt.hist(df['vr']);
plt.hist(dg['vr']);

# %%
# Now let's create a grid of 50x50 points in the range of -380 to -360 for mvr and 7 to 12 for dvr
mvr_grid = np.array(np.arange(-380, -360, .4))
dvr_grid = np.array(np.arange(7, 12, 0.1))

# %%
# for each pair of (mean(vr), dispersion(vr)), we define the following function to calculate the log(L) for all the stars in the dwarf galaxy Cas III
def log_Likelihood(mu, sigma, x):

    
    logL = -np.log(sigma * np.sqrt(2 * np.pi)) - ((x - mu)**2) / (2 * sigma**2)

    return logL

# %%
# for each pair of (mean(vr), dispersion(vr)), we define the following function to calculate the log(L) for all the stars in the dwarf galaxy Cas III
def log_Likelihood1(mvr, dvr, vr_dg):

    logL = np.log(1/(dvr * np.sqrt(2 * np.pi))*np.exp(-0.5*((vr_dg - mvr)/dvr)**2))

    return logL

# %%
# Then we crate a 2D array (matrix) to store the log(L) for each pair of (mean(vr), dispersion(vr)). The default value is 0.
logL_grid = np.zeros((len(mvr_grid), len(dvr_grid)))
print (logL_grid.shape)
# Out:
# (50, 50)

# %%
# We now can calculate the log(L) for each gridding point
for i in range(logL_grid.shape[0]):
    for j in range(logL_grid.shape[1]):
        logL_grid[i, j] = log_Likilihood(mvr_grid[i], dvr_grid[j], vr_cas3)

print (logL_grid)
# Out:
# [[-963.01685941 -956.07571392]
#  [-948.65049207 -942.11118307]
#  [-934.97636962 -928.81953459]]

# %%
print("Shapes:")
print("mvr_grid:", mvr_grid.shape)  # Should be (M,)
print("dvr_grid:", dvr_grid.shape)  # Should be (N,)
print("vr_cas3:", vr_cas3.shape)    # Should be (10,)
# Out:
# Shapes:
# mvr_grid: (50,)
# dvr_grid: (50,)
# vr_cas3: (212,)

# %%
# or we can use the braodcasting feature of numpy to calculate the log(L) for all gridding points at once
logL_grid = log_Likelihood(mvr_grid[:, np.newaxis, np.newaxis], dvr_grid[np.newaxis, :, np.newaxis], vr_cas3[np.newaxis, np.newaxis, :] )

# %%
logL_grid.shape
# Out:
# (50, 50, 212)

# %%
logL_2D = logL_grid[:, :, 0]

# %%
M, D = np.meshgrid(mvr_grid, dvr_grid)  # Shapes (50, 50)

# Plot
plt.figure(figsize=(8, 6))
contour = plt.contour(M, D, logL_2D, levels=20, cmap='viridis')
plt.colorbar(contour, label='log(Likelihood)')
plt.xlabel('mvr_grid')
plt.ylabel('dvr_grid')
plt.title('Log-Likelihood Contour Plot')
plt.grid(True)
plt.show()

# %%
# Here comes to the visualizations!
# Note that when we plot in contour and imshow, the 2D array need to be inverted !!
# This is the contour plot of logL, whic does not make too much senses

plt.figure(figsize=(8, 6))
contour = plt.contour(mvr_grid, dvr_grid, logL_grid.T)
plt.colorbar(contour)  # Add colorbar
plt.title('Basic Contour Plot')
plt.xlabel('mean(vr)')
plt.ylabel('velocity disersion (dvr)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 6
#       1 # Here comes to the visualizations!
#       2 # Note that when we plot in contour and imshow, the 2D array need to be inverted !!
#       3 # This is the contour plot of logL, whic does not make too much senses
#       5 plt.figure(figsize=(8, 6))
# ----> 6 contour = plt.contour(mvr_grid, dvr_grid, logL_grid.T)
#       7 plt.colorbar(contour)  # Add colorbar
#       8 plt.title('Basic Contour Plot')
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/pyplot.py:3143, in contour(data, *args, **kwargs)
#    3141 @_copy_docstring_and_deprecators(Axes.contour)
#    3142 def contour(*args, data=None, **kwargs) -> QuadContourSet:
# -> 3143     __ret = gca().contour(
#    3144         *args, **({"data": data} if data is not None else {}), **kwargs
#    3145     )
#    3146     if __ret._A is not None:  # type: ignore[attr-defined]
#    3147         sci(__ret)
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/__init__.py:1476, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1473 @functools.wraps(func)
#    1474 def inner(ax, *args, data=None, **kwargs):
#    1475     if data is None:
# -> 1476         return func(
#    1477             ax,
#    1478             *map(sanitize_sequence, args),
#    1479             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#    1481     bound = new_sig.bind(ax, *args, **kwargs)
#    1482     auto_label = (bound.arguments.get(label_namer)
#    1483                   or bound.kwargs.get(label_namer))
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/axes/_axes.py:6659, in Axes.contour(self, *args, **kwargs)
#    6650 """
#    6651 Plot contour lines.
#    6652
#    (...)
#    6656 %(contour_doc)s
#    6657 """
#    6658 kwargs['filled'] = False
# -> 6659 contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6660 self._request_autoscale_view()
#    6661 return contours
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/contour.py:813, in ContourSet.__init__(self, ax, levels, filled, linewidths, linestyles, hatches, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, nchunk, locator, transform, negative_linestyles, clip_path, *args, **kwargs)
#     809 if self.negative_linestyles is None:
#     810     self.negative_linestyles = \
#     811         mpl.rcParams['contour.negative_linestyle']
# --> 813 kwargs = self._process_args(*args, **kwargs)
#     814 self._process_levels()
#     816 self._extend_min = self.extend in ['min', 'both']
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/contour.py:1474, in QuadContourSet._process_args(self, corner_mask, algorithm, *args, **kwargs)
#    1471         corner_mask = mpl.rcParams['contour.corner_mask']
#    1472 self._corner_mask = corner_mask
# -> 1474 x, y, z = self._contour_args(args, kwargs)
#    1476 contour_generator = contourpy.contour_generator(
#    1477     x, y, z, name=self._algorithm, corner_mask=self._corner_mask,
#    1478     line_type=contourpy.LineType.SeparateCode,
#    1479     fill_type=contourpy.FillType.OuterCode,
#    1480     chunk_size=self.nchunk)
#    1482 t = self.get_transform()
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/contour.py:1514, in QuadContourSet._contour_args(self, args, kwargs)
#    1512 elif 2 < nargs <= 4:
#    1513     x, y, z_orig, *args = args
# -> 1514     x, y, z = self._check_xyz(x, y, z_orig, kwargs)
#    1516 else:
#    1517     raise _api.nargs_error(fn, takes="from 1 to 4", given=nargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/contour.py:1540, in QuadContourSet._check_xyz(self, x, y, z, kwargs)
#    1537 z = ma.asarray(z)
#    1539 if z.ndim != 2:
# -> 1540     raise TypeError(f"Input z must be 2D, not {z.ndim}D")
#    1541 if z.shape[0] < 2 or z.shape[1] < 2:
#    1542     raise TypeError(f"Input z must be at least a (2, 2) shaped array, "
#    1543                     f"but has shape {z.shape}")
#
# TypeError: Input z must be 2D, not 3D

# %%
# Let's get the likelihood values instead! 
# In order to do that, we need to the maximum likelihood vaues, as well as parameters that give the maximum likelihood
print (np.max(logL_grid))

max_indices = np.where(logL_grid == np.max(logL_grid))
max_row, max_col = max_indices[0][0], max_indices[1][0]

print (max_row, max_col)
print(mvr_grid[max_row], dvr_grid[max_col])
# Out:
# -780.2981773394497
# 21 26
# -371.6000000000005 9.59999999999999

# %%
# This is the contour plot of Likelihood, we want it to be normalized to the maximum value
levels = np.array([0.01, 0.1, 0.5, 0.99])
plt.figure(figsize=(4, 6))
contour = plt.contour(mvr_grid, dvr_grid, np.exp(logL_grid.T-np.max(logL_grid)), levels=levels)
plt.scatter(mvr_grid[max_row], dvr_grid[max_col], marker="+", color='red', s=100)
cbar = plt.colorbar(contour)  # Add colorbar

plt.title('Basic Contour Plot')
plt.xlabel('mean(vr)')
plt.ylabel('velocity disersion (dvr)')
plt.show()
